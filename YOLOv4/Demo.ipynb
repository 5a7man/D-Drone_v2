# %%
cd drive/MyDrive/CV_v2/YOLOV4_v2/darknet/
# Out:
# /content/drive/MyDrive/CV_v2/YOLOV4_v2/darknet

# %%
# !make
# !chmod +x ./darknet
# !sudo apt install dos2unix
# !dos2unix ./data/train.txt
# !dos2unix ./data/valid.txt
# !dos2unix ./data/test.txt
# !dos2unix ./data/drone.data
# !dos2unix ./data/drone.names
# !dos2unix ./cfg/drone.cfg
# Out:
# chmod +x *.sh
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# dos2unix is already the newest version (7.3.4-3).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# dos2unix: converting file ./data/train.txt to Unix format...
# dos2unix: converting file ./data/valid.txt to Unix format...
# dos2unix: converting file ./data/test.txt to Unix format...
# dos2unix: converting file ./data/drone.data to Unix format...
# dos2unix: converting file ./data/drone.names to Unix format...
# dos2unix: converting file ./cfg/drone.cfg to Unix format...

# %%
# file = 'Image0012.jpg'
# A = !python3 darknet_images.py --input {'data/test/'+file} --weight backup/drone_best.weights --config_file cfg/drone.cfg --data data/drone.data  --dont_show
# A[-1]
# from PIL import Image
# Image.open(A[-1])

# %%
# !python3 darknet_video.py --input data/videos/1.mp4 --out_filename Detect/out1.mp4 --weight backup/drone_best.weights --config_file cfg/drone.cfg --data data/drone.data --thresh 0.5 --dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Objects:
# FPS: 38
#
# Objects:
# Drone: 53.89%
# FPS: 37
#
# Objects:
# Drone: 64.06%
# FPS: 31
#
# Objects:
# Drone: 57.0%
# FPS: 32
#
# Objects:
# Drone: 65.8%
# FPS: 34
#
# Objects:
# FPS: 29
#
# Objects:
# FPS: 33
#
# Objects:
# Drone: 68.62%
# FPS: 32
#
# Objects:
# Drone: 69.34%
# FPS: 40
#
# Objects:
# FPS: 38
#
# Objects:
# FPS: 37
#
# Objects:
# FPS: 37
#
# Objects:
# Drone: 54.45%
# FPS: 37
#
# Objects:
# FPS: 37
#
# Objects:
# FPS: 37
#
# Objects:
# FPS: 38
#
# Objects:
# FPS: 39
#
# Objects:
# FPS: 38
#
# Objects:
# FPS: 38
#
# Objects:
# FPS: 38
#
# Objects:
# FPS: 39
#
# Objects:
# FPS: 39
#
# Objects:
# FPS: 39
#
# Objects:
# FPS: 39
#
# Objects:
# FPS: 38
#
# Objects:
# FPS: 38
#
# Objects:
# Drone: 73.46%
# FPS: 38
#
# Objects:
# Drone: 57.19%
# FPS: 35
#
# Objects:
# Drone: 50.75%
# FPS: 38
#
# Objects:
# FPS: 39
#
# Objects:
# Drone: 60.3%
# FPS: 39
#
# Objects:
# Drone: 59.44%
# FPS: 39
#
# Objects:
# ...
