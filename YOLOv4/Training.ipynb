# %%
cd drive/MyDrive/CV_v2/YOLOV4_v2/darknet/
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/CV_v2/YOLOV4_v2/darknet/'
# /content/drive/MyDrive/CV_v2/YOLOV4_v2/darknet

# %%
# !make
# !chmod +x ./darknet
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# !sudo apt install dos2unix
# !dos2unix ./data/train.txt
# !dos2unix ./data/drone.data
# !dos2unix ./data/drone.names
# !dos2unix ./cfg/drone.cfg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# dos2unix is already the newest version (7.3.4-3).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# dos2unix: converting file ./data/train.txt to Unix format...
# dos2unix: converting file ./data/drone.data to Unix format...
# dos2unix: converting file ./data/drone.names to Unix format...
# dos2unix: converting file ./cfg/drone.cfg to Unix format...

# %%
# !./darknet detector train data/drone.data cfg/drone.cfg yolov4.conv.137 -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.890507), count: 11, class_loss = 0.015313, iou_loss = 0.736773, total_loss = 0.752086
#  total_bbox = 799834, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.744356), count: 5, class_loss = 0.130175, iou_loss = 14.692271, total_loss = 14.822446
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.832817), count: 9, class_loss = 0.928257, iou_loss = 6.763587, total_loss = 7.691844
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.864975), count: 14, class_loss = 1.248211, iou_loss = 1.684445, total_loss = 2.932657
#  total_bbox = 799862, rewritten_bbox = 0.000000 %
# ...
