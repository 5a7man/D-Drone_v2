# %%
cd drive/MyDrive/CV_v2/YOLOV5_v2/yolov5_v2/
# Out:
# /content/drive/MyDrive/CV_v2/YOLOV5_v2/yolov5_v2

# %%
from PIL import Image
B  = !pip install -r requirements.txt

# %%
A = !python3 detect.py --weights "./runs/train/dronev5_results/weights/best.pt" --source "drone/images/test/Image0029.jpg" --img-size 416 --conf-thres 0.5 --iou-thres 0.5 --view-img --device cpu
print(A[-1])
display(Image.open(A[-2]))
# Out:
# Inference Time. (0.159s)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416 at 0x7FE3326A5290>

# %%
# !python3 detect.py --weights "./runs/train/dronev5_results/weights/best.pt" --source "drone/Videos/2.mp4" --img-size 416 --conf-thres 0.5 --iou-thres 0.5 --view-img 
# print(A[-1])
# display(Image.open(A[-2]))
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, img_size=416, iou_thres=0.5, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='drone/Videos/2.mp4', update=False, view_img=True, weights=['./runs/train/dronev5_results/weights/best.pt'])
# YOLOv5  torch 1.8.0+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPS
# video 1/1 (1/4289) /content/drive/My Drive/CV_v2/YOLOV5_v2/yolov5_v2/drone/Videos/2.mp4: 256x416 1 Drone, Done. (0.040s)
# here is image
# video 1/1 (2/4289) /content/drive/My Drive/CV_v2/YOLOV5_v2/yolov5_v2/drone/Videos/2.mp4: 256x416 1 Drone, Done. (0.010s)
# here is image
# video 1/1 (3/4289) /content/drive/My Drive/CV_v2/YOLOV5_v2/yolov5_v2/drone/Videos/2.mp4: 256x416 1 Drone, Done. (0.009s)
# here is image
# ...
