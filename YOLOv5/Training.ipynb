# %%
cd drive/MyDrive/CV_v2/YOLOV5_v2/yolov5_v2/

# %%
# !pip install -r requirements.txt 
# !pip install wandb

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python train.py --img 416 --batch 16 --epochs 100 --data 'drone_config.yaml' --cfg ./models/yolov5s.yaml --weights '' --name dronev5_results  --cache

# !python train.py --img 416 --batch 16 --epochs 50 --data 'drone_config.yaml' --weights 'yolov5s.pt' --name dronev5_results  --cache

# %%
# !python test.py --weights "./runs/train/dronev5_results/weights/best.pt" --data "drone_config.yaml" --img-size 416 --conf-thres 0.5 --iou-thres 0.5 --task test # --verbose   # --save-conf --save-txt  --save-json
