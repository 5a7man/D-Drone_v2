# %%
cd drive/MyDrive/YOLOVV5/yolov5

# %%
# !pip install -r requirements.txt

# %%
# !python train.py --img 416 --batch 16 --epochs 100 --data 'drone_config.yaml' --cfg ./models/yolov5s.yaml --weights '' --name dronev5_results  --cache

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
from utils.plots import plot_results  # plot results.txt as results.png
from IPython.display import Image
Image(filename='./runs/train/dronev5_results2/results.png', width=1000)
Image(filename='./runs/train/dronev5_results2/test_batch2_labels.jpg', width=900)

# %%
# !python detect.py --source "./Drone_Net_Dataset/" --weights './runs/train/dronev5_results2/weights/best.pt'
