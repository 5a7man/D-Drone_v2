# %%
cd drive/MyDrive/CV_v2/DETR/detr/
# Out:
# /content/drive/MyDrive/CV_v2/DETR/detr

# %%
# !python3 main.py --dataset_file drone --data_path ../dataset/ --output_dir output_model --resume weights/detr-r50-e632da11.pth
# Out:
# Output hidden; open in https://colab.research.google.com to view.
