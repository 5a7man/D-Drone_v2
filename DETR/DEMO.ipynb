# %%
cd drive/MyDrive/CV_v2/DETR/detr/
# Out:
# /content/drive/MyDrive/CV_v2/DETR/detr

# %%
a = !pip install -r requirements.txt

# %%
# !python3 test.py  --data_path  ../dataset/test/ --resume output_model/checkpoint.pth

# %%
from PIL import Image
import os
dir = 'Detect/exp/'
for filename in os.listdir(dir):
  display(Image.open(os.path.join(dir,filename)))
